# %% [markdown]
# # Lets Groww More Data Science Internship (VIP)
# ## Name : Akshada Khopade
# ## Title : Image to Pencil Sketch
# ## Level : Beginner
# ## Batch : March

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
#!pip install opencv-python
import cv2

# %% [markdown]
# ## Loading Original Image

# %%
image = cv2.imread('kr.webp')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ## Converting Image to GrayScale

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ## Inverting the Image

# %%
inv_img = 255 - gray_img
plt.imshow(cv2.cvtColor(inv_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ## Smoothing or Blurr image

# %%
blurred = cv2.GaussianBlur(inv_img, (21,21), 0)

# %% [markdown]
# ## Inverting the blured image

# %%
inv_blur = 255 - blurred
pencil_sketch = cv2.divide(gray_img, inv_blur, scale=256.0)
plt.imshow(cv2.cvtColor(pencil_sketch, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
